# %%
import pandas as pd

# %%
Data = pd.read_csv("weatherHistory.csv")
Data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
Data.shape
# Out:
# (96453, 12)

# %%
Data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
Data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
Data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
Data['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
Data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
Data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
Data['Summary'].value_counts()
# Out:
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [raw]
# Question: Find all the unique wind speed values in the given dataset?

# %%
Data['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %%
Data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [raw]
# Question: Find the number of times when he weather is exactly clear?

# %%
Data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
Data['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
Data.Summary.value_counts()
# Out:
# Summary
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
Data[Data.Summary == 'Clear']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
Data.groupby('Summary').get_group('Clear')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [raw]
# Question: Find the number of times at particular wind speed?

# %%
Data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
Data[Data['Wind Speed (km/h)'] == 8.05]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 309    2006-04-20 21:00:00.000 +0200          Clear        rain
# 957    2006-08-18 21:00:00.000 +0200  Partly Cloudy        rain
# 1530   2006-12-11 18:00:00.000 +0100          Foggy        rain
# 1977   2006-12-29 09:00:00.000 +0100       Overcast        snow
# 2333   2006-02-14 05:00:00.000 +0100          Clear        snow
# ...                              ...            ...         ...
# 95968  2016-09-18 19:00:00.000 +0200  Mostly Cloudy        rain
# 96001  2016-09-02 04:00:00.000 +0200          Clear        rain
# 96090  2016-09-22 21:00:00.000 +0200          Clear        rain
# 96094  2016-09-23 01:00:00.000 +0200          Clear        rain
# 96258  2016-09-29 21:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 309          12.266667                 12.266667      0.99               8.05
# ...

# %% [raw]
# Question: Find all the Null values in data?

# %%
Data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
Data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %% [raw]
# Question: Change the column name "Summary" to "Weather Conditions"

# %%
Data.rename(columns = {'Summary' : 'Weather Conditions'}, inplace = True)

# %%
Data.head()
# Out:
#                   Formatted Date Weather Conditions Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200      Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200      Partly Cloudy        rain
# 2  2006-04-01 02:00:00.000 +0200      Mostly Cloudy        rain
# 3  2006-04-01 03:00:00.000 +0200      Partly Cloudy        rain
# 4  2006-04-01 04:00:00.000 +0200      Mostly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89            14.1197
# 1         9.355556                  7.227778      0.86            14.2646
# 2         9.377778                  9.377778      0.89             3.9284
# 3         8.288889                  5.944444      0.83            14.1036
# 4         8.755556                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# ...

# %% [raw]
# Question: Find the mean of the column "Visibility" and "Wind Speed"

# %%
Data['Visibility (km)'].mean()
# Out:
# 10.347324929240148

# %%
Data['Wind Speed (km/h)'].mean()
# Out:
# 10.810640140793963

# %% [raw]
# Question: Find the Standard Deviation of the column "Visibility" and "Wind Speed"

# %%
Data['Visibility (km)'].std()
# Out:
# 4.192123191422925

# %%
Data['Wind Speed (km/h)'].std()
# Out:
# 6.9135710125921515

# %% [raw]
# Question: Find all the instances when Mostly Cloudy was recorded?

# %%
Data.columns
# Out:
# Index(['Formatted Date', 'Weather Conditions', 'Precip Type',
#        'Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Loud Cover', 'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
Data[Data['Weather Conditions'] == 'Mostly Cloudy' ]
# Out:
#                       Formatted Date Weather Conditions Precip Type  \
# 2      2006-04-01 02:00:00.000 +0200      Mostly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200      Mostly Cloudy        rain
# 17     2006-04-01 17:00:00.000 +0200      Mostly Cloudy        rain
# 18     2006-04-01 18:00:00.000 +0200      Mostly Cloudy        rain
# 19     2006-04-01 19:00:00.000 +0200      Mostly Cloudy        rain
# ...                              ...                ...         ...
# 96412  2016-09-08 07:00:00.000 +0200      Mostly Cloudy        rain
# 96413  2016-09-08 08:00:00.000 +0200      Mostly Cloudy        rain
# 96415  2016-09-08 10:00:00.000 +0200      Mostly Cloudy        rain
# 96416  2016-09-08 11:00:00.000 +0200      Mostly Cloudy        rain
# 96426  2016-09-08 21:00:00.000 +0200      Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
Data[Data['Weather Conditions'].str.contains('Mostly Cloudy')]
# Out:
#                       Formatted Date Weather Conditions Precip Type  \
# 2      2006-04-01 02:00:00.000 +0200      Mostly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200      Mostly Cloudy        rain
# 17     2006-04-01 17:00:00.000 +0200      Mostly Cloudy        rain
# 18     2006-04-01 18:00:00.000 +0200      Mostly Cloudy        rain
# 19     2006-04-01 19:00:00.000 +0200      Mostly Cloudy        rain
# ...                              ...                ...         ...
# 96412  2016-09-08 07:00:00.000 +0200      Mostly Cloudy        rain
# 96413  2016-09-08 08:00:00.000 +0200      Mostly Cloudy        rain
# 96415  2016-09-08 10:00:00.000 +0200      Mostly Cloudy        rain
# 96416  2016-09-08 11:00:00.000 +0200      Mostly Cloudy        rain
# 96426  2016-09-08 21:00:00.000 +0200      Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [raw]
# Question: Find all the entries where wind speed was above 5 km/h and visibility was 15?

# %%
Data[(Data['Wind Speed (km/h)'] > 5) & (Data['Visibility (km)'].between(15.5525, 15.5527))]
# Out:
#                       Formatted Date Weather Conditions Precip Type  \
# 817    2006-08-13 01:00:00.000 +0200      Mostly Cloudy        rain
# 2426   2006-02-18 02:00:00.000 +0100      Mostly Cloudy        rain
# 2427   2006-02-18 03:00:00.000 +0100      Mostly Cloudy        rain
# 2450   2006-02-19 02:00:00.000 +0100      Mostly Cloudy        rain
# 3146   2006-01-02 02:00:00.000 +0100           Overcast        rain
# ...                              ...                ...         ...
# 96422  2016-09-08 17:00:00.000 +0200      Partly Cloudy        rain
# 96440  2016-09-09 11:00:00.000 +0200      Partly Cloudy        rain
# 96443  2016-09-09 14:00:00.000 +0200      Partly Cloudy        rain
# 96446  2016-09-09 17:00:00.000 +0200      Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200      Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [raw]
# Question: What is the mean value of each column against Weather Conditions?

# %%
numeric_columns = Data.select_dtypes(include=['number'])
result = Data.groupby('Weather Conditions')[numeric_columns.columns].mean()
result
# Out:
#                                      Temperature (C)  \
# Weather Conditions
# Breezy                                      7.922016
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -0.510317
# Breezy and Mostly Cloudy                   11.093411
# Breezy and Overcast                         7.241614
# Breezy and Partly Cloudy                   12.492761
# Clear                                      11.925109
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    10.847578
# Dry                                        29.083660
# Dry and Mostly Cloudy                      26.838492
# Dry and Partly Cloudy                      26.605749
# Foggy                                       1.464035
# Humid and Mostly Cloudy                    20.886389
# Humid and Overcast                         21.515079
# Humid and Partly Cloudy                    21.568301
# ...

# %% [raw]
# Question: What is the min and max value of each column against Weather Conditions?

# %%
numeric_columns = Data.select_dtypes(include=['number'])
result1 = Data.groupby('Weather Conditions')[numeric_columns.columns].min()
result1
# Out:
#                                      Temperature (C)  \
# Weather Conditions
# Breezy                                     -2.777778
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -3.827778
# Breezy and Mostly Cloudy                   -6.966667
# Breezy and Overcast                       -11.533333
# Breezy and Partly Cloudy                   -5.050000
# Clear                                     -20.000000
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                     7.805556
# Dry                                        20.000000
# Dry and Mostly Cloudy                      20.072222
# Dry and Partly Cloudy                      20.000000
# Foggy                                     -21.822222
# Humid and Mostly Cloudy                    20.000000
# Humid and Overcast                         20.105556
# Humid and Partly Cloudy                    20.055556
# ...

# %%
numeric_columns = Data.select_dtypes(include=['number'])
result2 = Data.groupby('Weather Conditions')[numeric_columns.columns].max()
result2
# Out:
#                                      Temperature (C)  \
# Weather Conditions
# Breezy                                     37.588889
# Breezy and Dry                             21.111111
# Breezy and Foggy                           17.616667
# Breezy and Mostly Cloudy                   27.522222
# Breezy and Overcast                        22.433333
# Breezy and Partly Cloudy                   38.438889
# Clear                                      39.905556
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    17.844444
# Dry                                        38.750000
# Dry and Mostly Cloudy                      33.905556
# Dry and Partly Cloudy                      37.800000
# Foggy                                      23.661111
# Humid and Mostly Cloudy                    23.111111
# Humid and Overcast                         24.055556
# Humid and Partly Cloudy                    23.566667
# ...
